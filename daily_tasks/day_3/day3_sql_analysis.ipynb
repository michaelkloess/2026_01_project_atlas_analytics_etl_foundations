# %% [markdown]
# # Day 3 – SQL via Python: NYC School Data Exploration
# ---

# %% [markdown]
# ## Objective

# %% [markdown]
# Using Python and SQL together to explore real-world education data. </br>
# Connect to a PostgreSQL database, SQL queries, analyze school-level insights, and present insights in this notebook.

# %% [markdown]
# ---
# ## Install Libraries

# %%
#Installs required Python packages for data analysis, database abstraction, and PostgreSQL connectivity within the Jupyter Notebook

# %pip install pandas sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.45)
# Requirement already satisfied: psycopg2-binary in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.9.11)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Import Libraries

# %%
#Imports pandas for data manipulation and sqlalchemy for database connections and SQL operations

import pandas as pd 
import sqlalchemy as sa

# %% [markdown]
# ---
# ## Database Connection
#
# 1. Make a connection
# 2. Create an engine

# %%
#Defines the database connection URL for accessing a PostgreSQL database with SSL enabled

db_url = 'postgresql://neondb_owner:a9Am7Yy5r9_T7h4OF2GN@ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech:5432/neondb?sslmode=require'

# %%
#Sets up the database infrastructure by initializing the engine and establishing a connection
 
engine = sa.create_engine(db_url) #Creates a SQLAlchemy engine using the specified database connection URL
connection = engine.connect() #Opens a connection to the database via the created engine

# %%
#Loads multiple tables from the database into pandas DataFrames for further analysis

directory = pd.read_sql("SELECT * FROM nyc_schools.high_school_directory", engine) #Reads the high school directory table from the database into a DataFrame "directory"
demographics = pd.read_sql("SELECT * FROM nyc_schools.school_demographics", engine) #Reads the school demographics table from the database into a DataFrame "demographics"
safety_report = pd.read_sql("SELECT * FROM nyc_schools.school_safety_report", engine) #Reads the school safety report table from the database into a DataFrame "safety_report"

# %% [markdown]
# ---
# ## Initial Data Inspection

# %% [markdown]
# ### Table: directory

# %%
#Displays the first five rows of the directory DataFrame to quickly inspect its structure and contents

directory.head()
# Out:
#       dbn                                        school_name    borough  \
# 0  27Q260          Frederick Douglass Academy VI High School     Queens
# 1  21K559        Life Academy High School for Film and Music   Brooklyn
# 2  16K393     Frederick Douglass Academy IV Secondary School   Brooklyn
# 3  08X305                               Pablo Neruda Academy      Bronx
# 4  03M485  Fiorello H. LaGuardia High School of Music & A...  Manhattan
#
#   building_code  phone_number    fax_number  grade_span_min  grade_span_max  \
# 0          Q465  718-471-2154  718-471-2890             9.0              12
# 1          K400  718-333-7750  718-333-7775             9.0              12
# 2          K026  718-574-2820  718-574-2821             9.0              12
# 3          X450  718-824-1682  718-824-1663             9.0              12
# 4          M485  212-496-0700  212-724-5748             9.0              12
#
#    expgrade_span_min  expgrade_span_max start_time end_time  \
# 0                NaN                NaN    7:45 AM  2:05 PM
# 1                NaN                NaN    8:15 AM  3:00 PM
# 2                NaN                NaN    8:00 AM  2:20 PM
# 3                NaN                NaN    8:00 AM  3:50 PM
# 4                NaN                NaN    8:00 AM  4:00 PM
#
#                                           priority01  \
# 0  Priority to Queens students or residents who a...
# 1  Priority to New York City residents who attend...
# 2                 Priority to continuing 8th graders
# 3  Priority to Bronx students or residents who at...
# 4                    Open to New York City residents
#
#                                           priority02  \
# 0  Then to New York City residents who attend an ...
# 1                    Then to New York City residents
# 2  Then to Brooklyn students or residents who att...
# 3  Then to New York City residents who attend an ...
# 4  Admission is based on the outcome of a competi...
#
#                                           priority03  \
# 0               Then to Queens students or residents
# 1
# 2  Then to New York City residents who attend an ...
# 3                Then to Bronx students or residents
# 4  Students must audition for each program (studi...
#
#                                           priority04  \
# 0                    Then to New York City residents
# 1
# 2             Then to Brooklyn students or residents
# 3                    Then to New York City residents
# 4  Students must be residents of New York City at...
#
#                         priority05 priority06 priority07 priority08  \
# 0
# 1
# 2  Then to New York City residents
# 3
# 4
#
#   priority09 priority10 location phone_number2 school_email  \
# 0                           None          None         None
# 1                           None          None         None
# 2                           None          None         None
# 3                           None          None         None
# 4                           None          None         None
#
#                                         website  \
# 0  http://schools.nyc.gov/schoolportals/27/Q260
# 1  http://schools.nyc.gov/schoolportals/21/K559
# 2  http://schools.nyc.gov/schoolportals/16/K393
# 3                    www.pablonerudaacademy.org
# 4                           www.laguardiahs.org
#
#                                               subway  \
# 0                       A to Beach 25th St-Wavecrest
# 1  D to 25th Ave ; N to Ave U ; N to Gravesend - ...
# 2             J to Kosciusko St ; M, Z to Myrtle Ave
# 3                                                N/A
# 4  1 to 66th St - Lincoln Center ; 2, 3 to 72nd S...
#
#                                                bus grades2018 finalgrades  \
# 0                                        Q113, Q22       None        None
# 1                         B1, B3, B4, B6, B64, B82       None        None
# 2                B15, B38, B46, B47, B52, B54, Q24       None        None
# 3                      Bx22, Bx27, Bx36, Bx39, Bx5       None        None
# 4  M10, M104, M11, M20, M31, M5, M57, M66, M7, M72       None        None
#
#    total_students                         extracurricular_activities  \
# 0           412.0  After-school Program, Book, Writing, Homework ...
# 1           260.0  Film, Music, Talent Show, Holiday Concert, Stu...
# 2           155.0  After-school and Saturday Programs, Art Studio...
# 3           335.0  Youth Court, Student Government, Youth Service...
# 4          2730.0  Amnesty International, Anime, Annual Musical, ...
#
#                                        school_sports attendance_rate  \
# 0             Step Team, Modern Dance, Hip Hop Dance            None
# 1                                                               None
# 2                                    Basketball Team            None
# 3  Baseball, Basketball, Flag Football, Soccer, S...            None
# 4                                                               None
#
#   pct_stu_enough_variety pct_stu_safe school_accessibility_description  \
# 0                   None         None      Not Functionally Accessible
# 1                   None         None          Functionally Accessible
# 2                   None         None      Not Functionally Accessible
# 3                   None         None          Functionally Accessible
# 4                   None         None          Functionally Accessible
#
#   directions1 requirement1 requirement2 requirement3 requirement4  \
# 0        None         None         None         None         None
# 1        None         None         None         None         None
# 2        None         None         None         None         None
# 3        None         None         None         None         None
# 4        None         None         None         None         None
#
#   requirement5 program1 code1 interest1 method1 seats9ge1 grade9gefilledflag1  \
# 0         None     None  None      None    None      None                None
# 1         None     None  None      None    None      None                None
# 2         None     None  None      None    None      None                None
# 3         None     None  None      None    None      None                None
# 4         None     None  None      None    None      None                None
#
#   grade9geapplicants1 seats9swd1 grade9swdfilledflag1 grade9swdapplicants1  \
# 0                None       None                 None                 None
# 1                None       None                 None                 None
# 2                None       None                 None                 None
# 3                None       None                 None                 None
# 4                None       None                 None                 None
#
#                              campus_name building_borough building_location  \
# 0        Far Rockaway Educational Campus             None              None
# 1           Lafayette Educational Campus             None              None
# 2                                    N/A             None              None
# 3  Adlai E. Stevenson Educational Campus             None              None
# 4                                    N/A             None              None
#
#   latitude longitude community_board council_district census_tract        bin  \
# 0     None      None            None             None         None  4300730.0
# 1     None      None            None             None         None  3186454.0
# 2     None      None            None             None         None  3393805.0
# 3     None      None            None             None         None  2022205.0
# 4     None      None            None             None         None  1030341.0
#
#             bbl                                                nta zip_codes  \
# 0  4.157360e+09  Far Rockaway-Bayswater                        ...      None
# 1  3.068830e+09  Gravesend                                     ...      None
# 2  3.016160e+09  Stuyvesant Heights                            ...      None
# 3  2.036040e+09  Soundview-Castle Hill-Clason Point-Harding Par...      None
# 4  1.011560e+09  Lincoln Square                                ...      None
#
#   community_districts borough_boundaries city_council_districts  \
# 0                None               None                   None
# 1                None               None                   None
# 2                None               None                   None
# 3                None               None                   None
# 4                None               None                   None
#
#   police_precincts primary_address_line_1          city state_code postcode  \
# 0             None     8-21 Bay 25 Street  Far Rockaway         NY    11691
# 1             None     2630 Benson Avenue      Brooklyn         NY    11214
# 2             None  1014 Lafayette Avenue      Brooklyn         NY    11221
# 3             None  1980 Lafayette Avenue         Bronx         NY    10473
# 4             None   100 Amsterdam Avenue      New York         NY    10023
#
#           school_type                                 overview_paragraph  \
# 0                      Frederick Douglass Academy (FDA) VI High Schoo...
# 1                      At Life Academy High School for Film and Music...
# 2                      The Frederick Douglass Academy IV (FDA IV) Sec...
# 3                      Our mission is to engage, inspire, and educate...
# 4  Specialized School  We enjoy an international reputation as the fi...
#
#                                   program_highlights  \
# 0  Advisory, Graphic Arts Design, Teaching Intern...
# 1  College Now, iLEARN courses, Art and Film Prod...
# 2  College Now with Medgar Evers College, Fresh P...
# 3  Advanced Placement courses, Electives courses ...
# 4  Students have a daily program that includes bo...
#
#                      language_classes  \
# 0                             Spanish
# 1                             Spanish
# 2                     French, Spanish
# 3                             Spanish
# 4  French, Italian, Japanese, Spanish
#
#                            advancedplacement_courses  \
# 0  Calculus AB, English Language and Composition,...
# 1
# 2  English Language and Composition, United State...
# 3  Art History, English Language and Composition,...
# 4  Art History, Biology, Calculus AB, Calculus BC...
#
#                                    online_ap_courses online_language_courses  \
# 0                                 Biology, Physics B         French, Spanish
# 1  Biology, English Literature and Composition, E...
# 2                        French Language and Culture
# 3                                                                    Spanish
# 4                                                                    Spanish
#
#                                     psal_sports_boys  \
# 0  Basketball, Cross Country, Indoor Track, Outdo...
# 1  Basketball, Bowling, Indoor Track, Soccer, Sof...
# 2
# 3  Basketball, Outdoor Track, Softball, Tennis, V...
# 4  Basketball, Bowling, Cross Country, Fencing, G...
#
#                                    psal_sports_girls psal_sports_coed  \
# 0  Basketball, Cross Country, Indoor Track, Outdo...
# 1  Basketball, Bowling, Indoor Track, Soccer, Sof...          Cricket
# 2
# 3  Basketball, Outdoor Track, Softball, Tennis, V...
# 4  Basketball, Bowling, Cross Country, Fencing, G...
#
#                                          partner_cbo  \
# 0
# 1                        Coney Island Generation Gap
# 2  Achieving Change in our Neighborhood (Teen ACT...
# 3
# 4             Lincoln Center for the Performing Arts
#
#                                     partner_hospital  \
# 0  Jamaica Hospital Medical Center, Peninsula Hos...
# 1
# 2
# 3  Soundview Health Center, Bronx Lebanon Hospita...
# 4                         Mount Sinai Medical Center
#
#                                     partner_highered  \
# 0  York College, Brooklyn College, St. John's Col...
# 1  City Tech, Kingsborough Early College Secondar...
# 2                               Medgar Evers College
# 3  Hostos Community College, Monroe College, Lehm...
# 4  The Cooper Union for the Advancement of Scienc...
#
#                                     partner_cultural  \
# 0
# 1  Museum of the Moving Image, New York Public Li...
# 2                       Noel Pointer School of Music
# 3          Chilean Consulate, Materials for the Arts
# 4  Lincoln Center for the Performing Arts, Americ...
#
#                                    partner_nonprofit  \
# 0  Queens District Attorney, Sports and Arts Foun...
# 1                  Institute for Student Achievement
# 2  Hip-Hop 4 Life, Urban Arts, and St. Nicks Alli...
# 3  Network for Teaching Entrepreneurship (NFTE), ...
# 4  Junior Achievement, Red Cross, United Nations ...
#
#                                    partner_corporate partner_financial  \
# 0                                 Replications, Inc.          Citibank
# 1                  Film Life, Inc., SONY Wonder Tech
# 2
# 3
# 4  Sony Music, Warner Music Group, Capital Cities...
#
#                               partner_other  \
# 0  New York Road Runners Foundation (NYRRF)
# 1
# 2
# 3                                 iLearnNYC
# 4
#
#                                          addtl_info1  \
# 0  Uniform Required: plain white collared shirt, ...
# 1  Our school requires completion of a Common Cor...
# 2  Dress Code Required: solid white shirt/blouse,...
# 3  All students are individually programmed (base...
# 4                 Chancellor’s Arts Endorsed Diploma
#
#                                          addtl_info2  \
# 0  Extended Day Program, Student Summer Orientati...
# 1
# 2  Student Summer Orientation, Weekend Program of...
# 3                               Extended Day Program
# 4
#
#                                          se_services ell_programs  \
# 0  This school will provide students with disabil...          ESL
# 1  This school will provide students with disabil...          ESL
# 2  This school will provide students with disabil...          ESL
# 3  This school will provide students with disabil...          ESL
# 4  This school will provide students with disabil...          ESL
#
#   number_programs                                         Location 1  \
# 0               1  {'latitude': '40.601989336', 'longitude': '-73...
# 1               1  {'latitude': '40.593593811', 'longitude': '-73...
# 2               1  {'latitude': '40.692133704', 'longitude': '-73...
# 3               1  {'latitude': '40.822303765', 'longitude': '-73...
# 4               6  {'latitude': '40.773670507', 'longitude': '-73...
#
#   Community Board Council District Census Tract Zip Codes Community Districts  \
# 0              14               31       100802     20529                  51
# 1              13               47          306     17616                  21
# 2               3               36          291     18181                  69
# 3               9               18           16     11611                  58
# 4               7                6          151     12420                  20
#
#   Borough Boundaries City Council Districts Police Precincts
# 0                  3                     47               59
# 1                  2                     45               35
# 2                  2                     49               52
# 3                  5                     31               26
# 4                  4                     19               12

# %%
#Displays a concise summary of the directory DataFrame, including column names, data types, and non-null counts

directory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Columns: 105 entries, dbn to Police Precincts
# dtypes: float64(6), int64(1), object(98)
# memory usage: 357.0+ KB

# %%
#Generates descriptive statistics for the numeric columns in the directory DataFrame

directory.describe()
# Out:
#        grade_span_min  grade_span_max  expgrade_span_min  expgrade_span_max  \
# count      432.000000      435.000000          31.000000          33.000000
# mean         8.442130       11.894253           8.516129          12.363636
# std          1.164591        0.421583           1.121635           0.783349
# min          6.000000        9.000000           6.000000          12.000000
# 25%          9.000000       12.000000           9.000000          12.000000
# 50%          9.000000       12.000000           9.000000          12.000000
# 75%          9.000000       12.000000           9.000000          12.000000
# max          9.000000       12.000000           9.000000          14.000000
#
#        total_students           bin           bbl
# count      426.000000  4.310000e+02  4.310000e+02
# mean       703.842723  2.581724e+06  2.510921e+09
# std        775.870436  1.189750e+06  1.136455e+09
# min         50.000000  1.000811e+06  1.000160e+09
# 25%        349.000000  2.000992e+06  2.023060e+09
# 50%        460.500000  2.116159e+06  2.053680e+09
# 75%        622.000000  3.330710e+06  3.068830e+09
# max       5458.000000  5.149609e+06  5.066130e+09

# %%
#Calculates the number of missing (null) values in each column of the directory DataFrame

directory.isnull().sum()
# Out:
# dbn                       0
# school_name               0
# borough                   0
# building_code             0
# phone_number              0
#                          ..
# Zip Codes                 0
# Community Districts       0
# Borough Boundaries        0
# City Council Districts    0
# Police Precincts          0
# Length: 105, dtype: int64

# %%
#Counts the number of duplicate rows in the directory DataFrame

directory.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ---
# ### Table: demographics

# %%
#Inspects the demographics DataFrame and adjusts display settings to show all columns

demographics.head() #Displays the first few rows of the demographics DataFrame to preview its structure
pd.set_option('display.max_columns', None) #Configures pandas to display all columns and then outputs the full demographics DataFrame
demographics #Show Output
# Out:
#         dbn                                              Name  schoolyear  \
# 0    01M015                         P.S. 015 ROBERTO CLEMENTE    20052006
# 1    01M015                         P.S. 015 ROBERTO CLEMENTE    20062007
# 2    01M015                         P.S. 015 ROBERTO CLEMENTE    20072008
# 3    01M015                         P.S. 015 ROBERTO CLEMENTE    20082009
# 4    01M015                         P.S. 015 ROBERTO CLEMENTE    20092010
# ..      ...                                               ...         ...
# 238  01M064                               PS 064 ROBERT SIMON    20072008
# 239  01M064                               PS 064 ROBERT SIMON    20082009
# 240  01M064                               PS 064 ROBERT SIMON    20092010
# 241  01M064                               PS 064 ROBERT SIMON    20102011
# 242  01M064  PS 064 ROBERT SIMON                                 20112012
#
#     fl_percent  frl_percent  total_enrollment prek   k grade1 grade2 grade3  \
# 0         89.4          NaN               281   15  36     40     33     38
# 1         89.4          NaN               243   15  29     39     38     34
# 2         89.4          NaN               261   18  43     39     36     38
# 3         89.4          NaN               252   17  37     44     32     34
# 4                      96.5               208   16  40     28     32     30
# ..         ...          ...               ...  ...  ..    ...    ...    ...
# 238       79.3          NaN               295   26  48     49     47     36
# 239       79.3          NaN               300   26  44     48     53     47
# 240                    90.5               292   26  46     43     44     51
# 241                    90.5               322   32  53     47     45     40
# 242                    76.9               324   27  54     50     42     49
#
#     grade4 grade5 grade6 grade7 grade8 grade9 grade10 grade11 grade12  \
# 0       52     29     38
# 1       42     46
# 2       47     40
# 3       39     49
# 4       24     38
# ..     ...    ...    ...    ...    ...    ...     ...     ...     ...
# 238     46     43
# 239     38     44
# 240     50     32
# 241     52     53
# 242     48     54
#
#      ell_num  ell_percent  sped_num  sped_percent  ctt_num  selfcontained_num  \
# 0       36.0         12.8        57          20.3     25.0                9.0
# 1       38.0         15.6        55          22.6     19.0               15.0
# 2       52.0         19.9        60          23.0     20.0               14.0
# 3       48.0         19.0        62          24.6     21.0               17.0
# 4       40.0         19.2        46          22.1     14.0               14.0
# ..       ...          ...       ...           ...      ...                ...
# 238     17.0          5.8        68          23.1     37.0               11.0
# 239     15.0          5.0        73          24.3     43.0               22.0
# 240     13.0          4.5        88          30.1     49.0               24.0
# 241     21.0          6.5        98          30.4     64.0               18.0
# 242     29.0          9.0       102          31.5     55.0               28.0
#
#      asian_num  asian_per  black_num  black_per  hispanic_num  hispanic_per  \
# 0           10        3.6         74       26.3           189          67.3
# 1           18        7.4         68       28.0           153          63.0
# 2           16        6.1         77       29.5           157          60.2
# 3           16        6.3         75       29.8           149          59.1
# 4           16        7.7         67       32.2           118          56.7
# ..         ...        ...        ...        ...           ...           ...
# 238         12        4.1         70       23.7           206          69.8
# 239         17        5.7         72       24.0           200          66.7
# 240         17        5.8         67       22.9           192          65.8
# 241         22        6.8         79       24.5           200          62.1
# 242         26        8.0         76       23.5           193          59.6
#
#      white_num  white_per  male_num  male_per  female_num  female_per
# 0            5        1.8       158      56.2         123        43.8
# 1            4        1.6       140      57.6         103        42.4
# 2            7        2.7       143      54.8         118        45.2
# 3            7        2.8       149      59.1         103        40.9
# 4            6        2.9       124      59.6          84        40.4
# ..         ...        ...       ...       ...         ...         ...
# 238          5        1.7       149      50.5         146        49.5
# 239          5        1.7       162      54.0         138        46.0
# 240          9        3.1       152      52.1         140        47.9
# 241         14        4.3       179      55.6         143        44.4
# 242         24        7.4       184      56.8         140        43.2
#
# [243 rows x 38 columns]

# %%
#Displays a concise summary of the demographics DataFrame, including column names, data types, and non-null counts

demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dbn                243 non-null    object
#  1   Name               243 non-null    object
#  2   schoolyear         243 non-null    int64
#  3   fl_percent         243 non-null    object
#  4   frl_percent        104 non-null    float64
#  5   total_enrollment   243 non-null    int64
#  6   prek               243 non-null    object
#  7   k                  243 non-null    object
#  8   grade1             243 non-null    object
#  9   grade2             243 non-null    object
#  10  grade3             243 non-null    object
#  11  grade4             243 non-null    object
#  12  grade5             243 non-null    object
#  13  grade6             243 non-null    object
#  14  grade7             243 non-null    object
#  15  grade8             243 non-null    object
#  16  grade9             243 non-null    object
#  17  grade10            243 non-null    object
#  18  grade11            243 non-null    object
#  19  grade12            243 non-null    object
#  20  ell_num            239 non-null    float64
#  21  ell_percent        243 non-null    float64
#  22  sped_num           243 non-null    int64
#  23  sped_percent       243 non-null    float64
#  24  ctt_num            200 non-null    float64
#  25  selfcontained_num  211 non-null    float64
#  26  asian_num          243 non-null    int64
#  27  asian_per          243 non-null    float64
#  28  black_num          243 non-null    int64
#  29  black_per          243 non-null    float64
#  30  hispanic_num       243 non-null    int64
#  31  hispanic_per       243 non-null    float64
#  32  white_num          243 non-null    int64
#  33  white_per          243 non-null    float64
#  34  male_num           243 non-null    int64
#  35  male_per           243 non-null    float64
#  36  female_num         243 non-null    int64
#  37  female_per         243 non-null    float64
# dtypes: float64(12), int64(9), object(17)
# memory usage: 72.3+ KB

# %%
#Generates descriptive statistics for the numeric columns in the demographics DataFrame

demographics.describe()
# Out:
#          schoolyear  frl_percent  total_enrollment     ell_num  ell_percent  \
# count  2.430000e+02   104.000000        243.000000  239.000000   243.000000
# mean   2.008197e+07    77.683654        389.024691   52.167364    11.863374
# std    2.015634e+04    18.743165        213.035653   84.805296    13.838320
# min    2.005201e+07    19.600000         78.000000    1.000000     0.000000
# 25%    2.006201e+07    71.725000        246.500000   13.500000     5.000000
# 50%    2.008201e+07    82.050000        338.000000   30.000000     8.500000
# 75%    2.010201e+07    91.200000        476.500000   49.500000    13.100000
# max    2.011201e+07    99.700000       1613.000000  486.000000    87.500000
#
#          sped_num  sped_percent     ctt_num  selfcontained_num   asian_num  \
# count  243.000000    243.000000  200.000000         211.000000  243.000000
# mean    67.823045     19.432510   28.275000          19.033175   76.477366
# std     33.497958      7.909256   23.985954          11.881712  121.213537
# min      1.000000      0.200000    0.000000           0.000000    1.000000
# 25%     47.000000     15.950000    9.750000          10.000000   17.000000
# 50%     67.000000     21.700000   21.000000          17.000000   32.000000
# 75%     92.500000     24.050000   43.000000          27.000000   60.000000
# max    166.000000     35.500000  114.000000          58.000000  559.000000
#
#        ...   black_num   black_per  hispanic_num  hispanic_per   white_num  \
# count  ...  243.000000  243.000000    243.000000    243.000000  243.000000
# mean   ...   70.991770   20.324280    189.390947     52.103292   44.362140
# std    ...   34.196925    8.140595    103.313130     18.892945  105.479506
# min    ...   12.000000    2.100000     15.000000      2.900000    0.000000
# 25%    ...   44.500000   14.900000    116.000000     45.450000    7.000000
# 50%    ...   68.000000   20.600000    171.000000     57.700000   12.000000
# 75%    ...   87.000000   25.950000    269.500000     65.100000   31.500000
# max    ...  192.000000   45.400000    503.000000     80.100000  725.000000
#
#         white_per    male_num    male_per  female_num  female_per
# count  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     9.521399  197.872428   51.502881  191.152263   48.497119
# std     13.164749  103.299753    5.181933  113.588160    5.181933
# min      0.000000   37.000000   25.100000   41.000000   36.200000
# 25%      2.000000  128.500000   48.750000  121.000000   45.400000
# 50%      3.400000  175.000000   51.700000  173.000000   48.300000
# 75%      8.500000  242.500000   54.600000  229.500000   51.250000
# max     56.800000  794.000000   63.800000  819.000000   74.900000
#
# [8 rows x 21 columns]

# %% [markdown]
# # Table Overview

# %%
#Returns a list of all column names in the directory DataFrame

list(directory.columns)
# Out:
# ['dbn',
#  'school_name',
#  'borough',
#  'building_code',
#  'phone_number',
#  'fax_number',
#  'grade_span_min',
#  'grade_span_max',
#  'expgrade_span_min',
#  'expgrade_span_max',
#  'start_time',
#  'end_time',
#  'priority01',
#  'priority02',
#  'priority03',
#  'priority04',
#  'priority05',
#  'priority06',
#  'priority07',
#  'priority08',
#  'priority09',
#  'priority10',
#  'location',
#  'phone_number2',
#  'school_email',
#  'website',
#  'subway',
#  'bus',
#  'grades2018',
#  'finalgrades',
#  'total_students',
#  'extracurricular_activities',
#  'school_sports',
#  'attendance_rate',
#  'pct_stu_enough_variety',
#  'pct_stu_safe',
#  'school_accessibility_description',
#  'directions1',
#  'requirement1',
#  'requirement2',
#  'requirement3',
#  'requirement4',
#  'requirement5',
#  'program1',
#  'code1',
#  'interest1',
#  'method1',
#  'seats9ge1',
#  'grade9gefilledflag1',
#  'grade9geapplicants1',
#  'seats9swd1',
#  'grade9swdfilledflag1',
#  'grade9swdapplicants1',
#  'campus_name',
#  'building_borough',
#  'building_location',
#  'latitude',
#  'longitude',
#  'community_board',
#  'council_district',
#  'census_tract',
#  'bin',
#  'bbl',
#  'nta',
#  'zip_codes',
#  'community_districts',
#  'borough_boundaries',
#  'city_council_districts',
#  'police_precincts',
#  'primary_address_line_1',
#  'city',
#  'state_code',
#  'postcode',
#  'school_type',
#  'overview_paragraph',
#  'program_highlights',
#  'language_classes',
#  'advancedplacement_courses',
#  'online_ap_courses',
#  'online_language_courses',
#  'psal_sports_boys',
#  'psal_sports_girls',
#  'psal_sports_coed',
#  'partner_cbo',
#  'partner_hospital',
#  'partner_highered',
#  'partner_cultural',
#  'partner_nonprofit',
#  'partner_corporate',
#  'partner_financial',
#  'partner_other',
#  'addtl_info1',
#  'addtl_info2',
#  'se_services',
#  'ell_programs',
#  'number_programs',
#  'Location 1',
#  'Community Board',
#  'Council District',
#  'Census Tract',
#  'Zip Codes',
#  'Community Districts',
#  'Borough Boundaries',
#  'City Council Districts',
#  'Police Precincts']

# %%
#Returns a list of all column names in the demographics DataFrame

list(demographics.columns)
# Out:
# ['dbn',
#  'Name',
#  'schoolyear',
#  'fl_percent',
#  'frl_percent',
#  'total_enrollment',
#  'prek',
#  'k',
#  'grade1',
#  'grade2',
#  'grade3',
#  'grade4',
#  'grade5',
#  'grade6',
#  'grade7',
#  'grade8',
#  'grade9',
#  'grade10',
#  'grade11',
#  'grade12',
#  'ell_num',
#  'ell_percent',
#  'sped_num',
#  'sped_percent',
#  'ctt_num',
#  'selfcontained_num',
#  'asian_num',
#  'asian_per',
#  'black_num',
#  'black_per',
#  'hispanic_num',
#  'hispanic_per',
#  'white_num',
#  'white_per',
#  'male_num',
#  'male_per',
#  'female_num',
#  'female_per']

# %%
#Returns a list of all column names in the safety_report DataFrame

list(safety_report.columns)
# Out:
# ['school_year',
#  'building_code',
#  'dbn',
#  'location_name',
#  'location_code',
#  'address',
#  'borough',
#  'geographical_district_code',
#  'register',
#  'building_name',
#  'num_schools',
#  'schools_in_building',
#  'major_n',
#  'oth_n',
#  'nocrim_n',
#  'prop_n',
#  'vio_n',
#  'engroupa',
#  'rangea',
#  'avgofmajor_n',
#  'avgofoth_n',
#  'avgofnocrim_n',
#  'avgofprop_n',
#  'avgofvio_n',
#  'borough_name',
#  'postcode',
#  'latitude',
#  'longitude',
#  'community_board',
#  'council_district',
#  'census_tract',
#  'bin',
#  'bbl',
#  'nta',
#  '_schools']

# %% [markdown]
# # Questions

# %% [markdown]
# #### School Distribution

# %% [markdown]
# ##### How many schools are there in each borough?

# %%
#Defines and executes an SQL query to aggregate the number of schools per borough based on joined tables
#Creates a multi-line SQL query that counts distinct schools per borough and orders the results by count

query = """
        SELECT 
          hsd.borough AS borough,
          COUNT(DISTINCT(hsd.dbn)) AS cnt_schools
        FROM nyc_schools.high_school_directory AS hsd
        JOIN nyc_schools.school_safety_report AS ssr
        ON hsd.dbn = ssr.dbn
        GROUP BY hsd.borough
        ORDER BY cnt_schools DESC;
        """

pd.read_sql(query, engine) #Executes the SQL query against the database engine and returns the result as a pandas DataFrame
# Out:
#          borough  cnt_schools
# 0       Brooklyn          121
# 1          Bronx          118
# 2      Manhattan          106
# 3         Queens           80
# 4  Staten Island           10

# %% [markdown]
# #### Language Learners

# %% [markdown]
# ##### What is the average % of English Language Learners (ELL) per borough?

# %%
#Defines and executes an SQL query to calculate the average percentage of English Language Learners per borough
#Creates a multi-line SQL query that joins school directory and demographics data and orders results by average percentage

query = """
        SELECT
          hsd.borough,
          AVG(sd.ell_percent) AS avg_perc_ell
        FROM nyc_schools.high_school_directory hsd
        LEFT JOIN nyc_schools.school_demographics sd
          ON TRIM(UPPER(hsd.dbn)) = TRIM(UPPER(sd.dbn))
        GROUP BY hsd.borough
        ORDER BY avg_perc_ell ASC;
        """ 

pd.read_sql(query, engine) #Executes the SQL query against the database engine and returns the result as a pandas DataFrame
# Out:
#          borough  avg_perc_ell
# 0      Manhattan        7.5725
# 1         Queens           NaN
# 2       Brooklyn           NaN
# 3  Staten Island           NaN
# 4          Bronx           NaN

# %% [markdown]
# #### School supporting special needs

# %% [markdown]
# ##### Write a query to find the top 3 schools in each borough with the highest percentage of special education students

# %%
#Defines and executes an SQL query to identify the top three schools per borough by special education percentage
#Creates a multi-step SQL query using CTEs to aggregate, rank, and filter schools within each borough

query = """
        WITH per_school AS (
          SELECT
            TRIM(UPPER(dbn)) AS dbn,
            sped_percent
          FROM nyc_schools.school_demographics
          WHERE sped_percent IS NOT NULL
        ),
        ranked AS (
          SELECT
            hsd.borough,
            ps.sped_percent,
            ROW_NUMBER() OVER (PARTITION BY hsd.borough ORDER BY ps.sped_percent DESC) AS rank
          FROM nyc_schools.high_school_directory AS hsd
          JOIN per_school AS ps
            ON TRIM(UPPER(hsd.dbn)) = ps.dbn
          WHERE hsd.borough IS NOT NULL
        )
        SELECT
          borough,
          sped_percent,
          rank
        FROM ranked
        WHERE rank <= 3
        ORDER BY borough, rank;
        """

pd.read_sql(query, engine) #Executes the SQL query against the database engine and returns the result as a pandas DataFrame
# Out:
#      borough  sped_percent  rank
# 0  Manhattan          28.8     1
# 1  Manhattan          27.7     2
# 2  Manhattan          26.7     3

# %% [markdown]
# # Summary

# %% [markdown]
# ##### Question 1
#
# How many schools are there in each borough?
#
# The results show that the number of high schools varies substantially across boroughs, ranging from **10 to 121 schools**. **Brooklyn (121), the Bronx (118), and Manhattan (106)** have the highest counts, while **Queens (80)** and especially **Staten Island (10)** have significantly fewer schools.

# %% [markdown]
# ##### Question 2
#
# What is the average % of English Language Learners (ELL) per borough?
#
# The results show that **Manhattan** has an average **ELL percentage of 7.57%**, while **no valid ELL averages are available** for **Queens, Brooklyn, Staten Island, and the Bronx** due to missing or non-aggregable data in the demographics table.

# %% [markdown]
# ##### Question 3
#
# Find the top 3 schools in each borough with the highest percentage of special education students
#
# The results show that only **Manhattan** has sufficient data to identify the top three schools by special education percentage, with values ranging from **25.1% to 28.8%**. No ranked results are returned for the other boroughs due to missing or unavailable special education data.
